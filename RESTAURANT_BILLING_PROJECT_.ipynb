# %%
while True:
    import random
    r=random.randint(1000,10000)
    from datetime import date
    
    today =date.today()
    d= today.strftime("%m/%d/%Y, %H:%M:%S")

    print(" ")
    #import pyttsx3
    #s=pyttsx3.init()
    #s.say("WELLCOME TO LITTLE BIT SPICY dote COM")
    #s.runAndWait()
    
    
    
    print("             |--------------------------------|              ")
    print("             |  WELCOME TO LITTLE BIT SPICY   |              ")
    print("             |       ****************         |              ")
    print("             |--------------------------------|              ")
    
    print(" ")
    print(" ")
    
    category=int(input(" SOUPS : "))
    if category==1:
        print("  |------------------------------------------------------------------|      ")
        print("  |  NAME OF DISH        |  QUANTITY  | RATE  |  AMOUNT  |  DISCOUNT |      ")
        print("  |------------------------------------------------------------------|      ")
        print("  |1.SCHEZWAN SOUP       |     1       | 120  |  120.00 |      0     |      ")
        print("  |2.MANCHOW  SOUP       |     1       | 120  |  120.00 |      0     |      ")
        print("  |3.CHICKEN  SOUP       |     1       | 120  |  120.00 |      0     |      ")
        print("  |4.HOT-N-SOUR          |     1       | 120  |  120.00 |      0     |      ")
        print("  |5.SWEETCORN SOUP      |     1       | 120  |  120.00 |      0     |      ")
        print("  |------------------------------------------------------------------|      ")
        
    
    dish_name=int(input("enter your dish number :"))
    quantity=int(input("enter your quantity : "))
    if dish_name==1:
        dish="SCHEZWAN SOUP"
        amount=120
        total_price=(quantity*amount)
    elif dish_name==2:
        dish="MANCHOW  SOUP"
        amount=120
        total_price=(quantity*amount)
    elif dish_name==3:
        dish="CHICKEN  SOUP"
        amount=120
        total_price=(quantity*amount)
    elif dish_name==4:
        dish="HOT-N-SOUR"
        amount=120
        total_price=(quantity*amount)
    elif dish_name==5:
        dish="SWEETCORN SOUP"
        amount=120
        total_price=(quantity*amount)
    else:
        print("invalid choice")
        
        
    name=input("enter your name : ")
    while True:
        phone=input("enter phone number : ")
        if len(phone)==10:
            break
        else:
            print("please enter a valid 10 digit number")
            continue
    add=input("enter address : ")
    while True:
        pin=input("enter pincode")
        if len(pin)==6:
             break
        else:
            print("enter a valid 6digit pincode")
            continue
    while True:
        payment_by=input("payment details: ")
        
        print("                                                                                        ")
        print(f"|-------------------------------------------------------------------------------------|")
        print(f"|                                  BILL MEMO                                          |")
        print(f"|-------------------------------------------------------------------------------------|")
        print(f"| BILL NO : {r}                phone.no : {phone}           DATE : {today}     |")
        print(f"|                                                                                     |")
        print(f"| CUSTOMER NAME : {name}                                                                |")
        print(f"|                                                                                     |")
        print(f"| ORDERED DISH  : {dish}                                                              |")
        print(f"|                                                                                     |")
        print(f"| QUANTITY      : {quantity}   AMOUNT:{amount}                                        |")
        print(f"|                                                                                     |")
        print(f"|                                                                                     |")
        print(f"|                                                                                     |")
        print(f"|                                                                                     |")
        print(f"|-------------------------------------------------------------------------------------|")
        print(f"|                                                   TOTAL AMOUNT : {total_price}                |")
        print(f"|-------------------------------------------------------------------------------------|")
        break
# Out:
#
#              |--------------------------------|
#              |  WELCOME TO LITTLE BIT SPICY   |
#              |       ****************         |
#              |--------------------------------|
#
#
#  SOUPS : 1
#   |------------------------------------------------------------------|
#   |  NAME OF DISH        |  QUANTITY  | RATE  |  AMOUNT  |  DISCOUNT |
#   |------------------------------------------------------------------|
#   |1.SCHEZWAN SOUP       |     1       | 120  |  120.00 |      0     |
#   |2.MANCHOW  SOUP       |     1       | 120  |  120.00 |      0     |
#   |3.CHICKEN  SOUP       |     1       | 120  |  120.00 |      0     |
#   |4.HOT-N-SOUR          |     1       | 120  |  120.00 |      0     |
#   |5.SWEETCORN SOUP      |     1       | 120  |  120.00 |      0     |
#   |------------------------------------------------------------------|
# enter your dish number :5
# enter your quantity : 4
# enter your name : paara
# enter phone number : 1234554321
# ...

# %%
        4

# %%
12345678
